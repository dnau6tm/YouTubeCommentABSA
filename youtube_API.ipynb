# %%
pip install google-api-python-client

# %%
import os
from googleapiclient.discovery import build
import pandas as pd
import json

# %%
api_key = 'AIzaSyDsz7nLrMSG9T-kQNAo-QDED-18QDYQYi8'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
video_id = 'yW8hd9WvJ5A'

# %%
comments = []
author_display_names = []
published_ats = []
like_counts = []

df = pd.DataFrame()

next_page_token = None
while True:
  results = youtube.commentThreads().list(
      part='snippet, replies',
      videoId=video_id,
      textFormat='plainText',
      #order='relevance',
      #maxResults=120,
      pageToken=next_page_token
  ).execute()

  for item in results['items']:
      temp = item['snippet']['topLevelComment']['snippet']
      author_display_name = temp['authorDisplayName']
      published_at = temp['publishedAt']
      like_count = temp['likeCount']
      comment = temp['textDisplay']
      comments.append(comment)

  next_page_token = results.get('nextPageToken')
  if not next_page_token:
    break
df_temp = pd.DataFrame({'Comment':comments})
df = pd.concat([df, df_temp], axis = 0, ignore_index=True)
df
# Out:
#                                                 Comment
# 0                                   xin ảnh nền ad ơi
# 1                                                     .
# 2     Muốn lấy ảnh trong video quá mà ko biết lấy th...
# 3                                                     🥰
# 4                                     tuyệt vời quá lun
# ...                                                 ...
# 1885  Hình nền hợp với tên album!! Ad cho xin ảnh nề...
# 1886      List này hay wa cho mình xin link mp3 dc hk ạ
# 1887  Mình xin file hình nền được không bạn, đẹp quá...
# 1888                                            Wanbi ♡
# 1889              Bạn cho mình file hình nền với nhé ^^
#
# [1890 rows x 1 columns]

# %%
df.to_csv('youtube.csv', index=False)
